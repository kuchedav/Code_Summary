# %%
import plotly.plotly as py
from plotly.graph_objs import *

data = [Bar(x=df.School,
            y=df.Gap)]

py.iplot(data, filename='basic_bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~david.kuchelmeister/6.embed" height="525px" width="100%"></iframe>

# %%
# Get this figure: fig = py.get_figure("https://plot.ly/~Dreamshot/587/")
# Get this figure's data: data = py.get_figure("https://plot.ly/~Dreamshot/587/").get_data()
# Add data to this figure: py.plot(Data([Scatter(x=[1, 2], y=[2, 3])]), filename ="Netflix: Rebuffering.Slow Loading Calls (20% Sample)", fileopt="extend")
# Get y data of first trace: y1 = py.get_figure("https://plot.ly/~Dreamshot/587/").get_data()[0]["y"]

# Get figure documentation: https://plot.ly/python/get-requests/
# Add data documentation: https://plot.ly/python/file-options/

# If you're using unicode in your file, you may need to specify the encoding.
# You can reproduce this figure in Python with the following code!

# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api

import plotly
plotly.tools.set_credentials_file(username='david.kuchelmeister', api_key='lqsXmUc8NS3zMJimeN3C')
plotly.tools.set_config_file(world_readable=True,sharing='public')

import plotly.plotly as py
from plotly.graph_objs import *
trace1 = {
  "x": ["2012-09-01", "2012-10-01", "2012-11-01", "2012-12-01", "2013-01-01", "2013-02-01", "2013-03-01", "2013-04-01", "2013-05-01", "2013-06-01", "2013-07-01", "2013-08-01", "2013-09-01", "2013-10-01", "2013-11-01", "2013-12-01", "2014-01-01", "2014-02-01", "2014-03-01", "2014-04-01", "2014-05-01"], 
  "y": ["116", "337", "316", "337", "432", "432", "432", "443", "548", "527", "569", "706", "759", "780", "1391", "2498", "3393", "3931", "3183", "3288", "2993"], 
  "line": {
    "color": "rgb(214, 39, 40)", 
    "shape": "spline", 
    "width": 6
  }, 
  "name": "# of Calls", 
  "type": "scatter", 
  "uid": "c6cbae", 
  "xsrc": "Dreamshot:3951:10e225", 
  "ysrc": "Dreamshot:3951:cfef8c"
}
data = Data([trace1])
layout = {
  "annotations": [
    {
      "x": 1.39127282087e+12, 
      "y": 4.98148148148, 
      "align": "center", 
      "arrowcolor": "", 
      "arrowhead": 0, 
      "arrowsize": 1, 
      "arrowwidth": 0, 
      "ax": -1, 
      "ay": -420.5, 
      "bgcolor": "rgba(0,0,0,0)", 
      "bordercolor": "", 
      "borderpad": 1, 
      "borderwidth": 1.5, 
      "font": {
        "color": "", 
        "family": "", 
        "size": 0
      }, 
      "opacity": 1, 
      "showarrow": True, 
      "text": "&nbsp;", 
      "textangle": 0, 
      "xanchor": "auto", 
      "xref": "x", 
      "yanchor": "auto", 
      "yref": "y"
    }, 
    {
      "x": 1389492990000, 
      "y": 933.5, 
      "align": "center", 
      "arrowcolor": "", 
      "arrowhead": 5, 
      "arrowsize": 0.8, 
      "arrowwidth": 0, 
      "ax": -137, 
      "ay": 71.5, 
      "bgcolor": "rgba(0,0,0,0)", 
      "bordercolor": "", 
      "borderpad": 1, 
      "borderwidth": 0.6, 
      "font": {
        "color": "", 
        "family": "", 
        "size": 0
      }, 
      "opacity": 1, 
      "showarrow": True, 
      "text": "Feb., 2014: Netflix reluctantly agrees to pay Comcast<br>to directly connect to its network", 
      "textangle": 0, 
      "xanchor": "auto", 
      "xref": "x", 
      "yanchor": "auto", 
      "yref": "y"
    }
  ], 
  "autosize": False, 
  "bargap": 0.2, 
  "bargroupgap": 0, 
  "barmode": "group", 
  "boxgap": 0.3, 
  "boxgroupgap": 0.3, 
  "boxmode": "overlay", 
  "dragmode": "zoom", 
  "font": {
    "color": "#444", 
    "family": "\"Open sans\", verdana, arial, sans-serif", 
    "size": 12
  }, 
  "height": 600, 
  "hidesources": False, 
  "hovermode": "x", 
  "legend": {
    "x": 0.053125, 
    "y": 0.940476190476, 
    "bgcolor": "#fff", 
    "bordercolor": "#444", 
    "borderwidth": 0, 
    "font": {
      "color": "", 
      "family": "", 
      "size": 0
    }, 
    "traceorder": "normal", 
    "xanchor": "left", 
    "yanchor": "top"
  }, 
  "margin": {
    "r": 80, 
    "t": 100, 
    "autoexpand": True, 
    "b": 80, 
    "l": 80, 
    "pad": 0
  }, 
  "paper_bgcolor": "#fff", 
  "plot_bgcolor": "rgba(217, 217, 217, 0.4)", 
  "separators": ".,", 
  "showlegend": False, 
  "title": "Slow Comcast Speeds Were Costing Netflix Customers<br><br>Calls to Netflix: Rebuffering/Slow Loading (20% Sample)", 
  "titlefont": {
    "color": "", 
    "family": "", 
    "size": 0
  }, 
  "width": 800, 
  "xaxis": {
    "anchor": "y", 
    "autorange": False, 
    "autotick": True, 
    "domain": [0, 1], 
    "dtick": "M2", 
    "exponentformat": "B", 
    "gridcolor": "rgb(255, 255, 255)", 
    "gridwidth": 1, 
    "linecolor": "#444", 
    "linewidth": 1, 
    "mirror": False, 
    "nticks": 11, 
    "overlaying": False, 
    "position": 0, 
    "range": [1343793600000, 1401595200000], 
    "rangemode": "normal", 
    "showexponent": "all", 
    "showgrid": True, 
    "showline": False, 
    "showticklabels": True, 
    "tick0": 946702800000, 
    "tickangle": "auto", 
    "tickcolor": "#444", 
    "tickfont": {
      "color": "", 
      "family": "", 
      "size": 0
    }, 
    "ticklen": 5, 
    "ticks": "", 
    "tickwidth": 1, 
    "title": "Source & Data: <a href=\"http://tinyurl.com/qy36opl\">Pg. 126, FCC Report: Netflix vs. Comcast & TWC</a>", 
    "titlefont": {
      "color": "", 
      "family": "", 
      "size": 0
    }, 
    "type": "date", 
    "zeroline": True, 
    "zerolinecolor": "#444", 
    "zerolinewidth": 1
  }, 
  "yaxis": {
    "anchor": "x", 
    "autorange": True, 
    "autotick": True, 
    "domain": [0, 1], 
    "dtick": 500, 
    "exponentformat": "B", 
    "gridcolor": "rgb(255, 255, 255)", 
    "gridwidth": 1, 
    "linecolor": "#444", 
    "linewidth": 1, 
    "mirror": False, 
    "nticks": 0, 
    "overlaying": False, 
    "position": 0, 
    "range": [-95.9444444444, 4142.94444444], 
    "rangemode": "normal", 
    "showexponent": "all", 
    "showgrid": True, 
    "showline": False, 
    "showticklabels": True, 
    "tick0": 0, 
    "tickangle": "auto", 
    "tickcolor": "#444", 
    "tickfont": {
      "color": "", 
      "family": "", 
      "size": 0
    }, 
    "ticklen": 5, 
    "ticks": "", 
    "tickwidth": 1, 
    "title": "# of Calls", 
    "titlefont": {
      "color": "", 
      "family": "", 
      "size": 0
    }, 
    "type": "linear", 
    "zeroline": True, 
    "zerolinecolor": "#444", 
    "zerolinewidth": 1
  }
}
fig = Figure(data=data, layout=layout)
plot_url = py.plot(fig)
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-12-41af1e36c77d> in <module>()
#     231 }
#     232 fig = Figure(data=data, layout=layout)
# --> 233 plot_url = py.plot(fig)
#
# /anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     231     data = fig.get('data', [])
#     232     plot_options['layout'] = fig.get('layout', {})
# --> 233     response = v1.clientresp(data, **plot_options)
#     234
#     235     # Check if the url needs a secret key
#
# /anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# ...
